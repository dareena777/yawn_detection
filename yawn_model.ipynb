# %%
import os
import cv2
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Dense, Flatten
import warnings
warnings.filterwarnings('ignore')
# Out:
# WARNING:tensorflow:From c:\Users\Dareen\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
path = "C:/Users/Dareen/OneDrive/Desktop/graduation/yawn_detection/dataset_new"
print(os.listdir(path))
# Out:
# ['test', 'train']

# %%
train_path = path + '/train'
test_path = path + '/test'

# %%
train_classes = os.listdir(train_path)
print(train_classes)
test_classes = os.listdir(test_path)
print(test_classes)
# Out:
# ['Closed', 'no_yawn', 'Open', 'yawn']
# ['Closed', 'no_yawn', 'Open', 'yawn']

# %%
img_size = 224
no_channel = 3

# %%
X_tr = []
y_tr = []
for label in train_classes:
    data_path = os.path.join(train_path, label)
    class_num = train_classes.index(label)
    for img in os.listdir(data_path):
            try:
                img_arr = cv2.imread(os.path.join(data_path, img))[...,::-1]
                resized_arr = cv2.resize(img_arr, (img_size, img_size))
                X_tr.append(resized_arr)
                y_tr.append(class_num)
            except Exception as e:
                print(e)

# %%
X_tr = np.asarray(X_tr)
X_tr = X_tr/255
y_tr = np.asarray(y_tr)
y_tr = to_categorical(y_tr)

# %%
X_tr, X_val, y_tr, y_val = train_test_split(X_tr, y_tr, test_size = 0.2, random_state = 1)

# %%
X_test = []
y_test = []
for label in test_classes:
    data_path = os.path.join(test_path, label)
    class_num = test_classes.index(label)
    for img in os.listdir(data_path):
            try:
                img_arr = cv2.imread(os.path.join(data_path, img))[...,::-1]
                resized_arr = cv2.resize(img_arr, (img_size, img_size))
                X_test.append(resized_arr)
                y_test.append(class_num)
            except Exception as e:
                print(e)

# %%
X_test = np.asarray(X_test)
X_test = X_test/255
y_test = np.asarray(y_test)
y_test = to_categorical(y_test)

# %%
print('X pelatihan shape :', X_tr.shape)
print('y pelatihan shape :', y_tr.shape)
print('X validasi shape :', X_val.shape)
print('y validasi shape :', y_val.shape)
print('X pengujian shape :', X_test.shape)
print('y pengujian shape :', y_test.shape)
# Out:
# X pelatihan shape : (1973, 224, 224, 3)
# y pelatihan shape : (1973, 4)
# X validasi shape : (494, 224, 224, 3)
# y validasi shape : (494, 4)
# X pengujian shape : (433, 224, 224, 3)
# y pengujian shape : (433, 4)

# %%
datagen = ImageDataGenerator(
        featurewise_center = False, # set input mean to 0 over the dataset
        samplewise_center = False, # set each sample mean to 0
        featurewise_std_normalization = False, # divide inputs by std of the dataset
        samplewise_std_normalization = False, # divide each input by its std
        zca_whitening = False, # apply ZCA whitening
        rotation_range = 0, # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.25, # Randomly zoom image
        width_shift_range = 0.125, # randomly shift images horizontally (fraction of total width)
        height_shift_range = 0.125, # randomly shift images vertically (fraction of total height)
        horizontal_flip = True, # randomly flip images
        vertical_flip = False) # randomly flip images
datagen.fit(X_tr)

# %%
model = Sequential([
    Conv2D(filters = 32, kernel_size = 3, activation = 'relu', input_shape = (img_size, img_size, no_channel)),
    MaxPooling2D(),
    Conv2D(filters = 64, kernel_size = 3, activation = 'relu'),
    MaxPooling2D(),
    Conv2D(filters = 128, kernel_size = 3, activation = 'relu'),
    MaxPooling2D(),
    Flatten(),
    Dense(units = 128, activation =  'relu'),
    Dense(units = 64, activation =  'relu'),
    Dense(units = 32, activation =  'relu'),
    Dropout(rate = 0.5),
    Dense(units = 4, activation = 'softmax')
])
# Out:
# WARNING:tensorflow:From c:\Users\Dareen\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\Dareen\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 111, 111, 32)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 54, 54, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 26, 26, 128)       0
#  g2D)
#
#  flatten (Flatten)           (None, 86528)             0
#
#  dense (Dense)               (None, 128)               11075712
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_3 (Dense)             (None, 4)                 132
#
# =================================================================
# Total params: 11179428 (42.65 MB)
# Trainable params: 11179428 (42.65 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss = 'categorical_crossentropy', 
              optimizer = 'adam',
              metrics = ['accuracy'])
# Out:
# WARNING:tensorflow:From c:\Users\Dareen\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
epochs = 50

# %%
hist = model.fit(X_tr,
                 y_tr,
                 epochs = epochs,
                 validation_data = (X_val, y_val))
# Out:
# Epoch 1/50
# WARNING:tensorflow:From c:\Users\Dareen\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\Dareen\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
#
ms/step - loss: 0.0598 - accuracy: 0.9797 - val_loss: 0.3486 - val_accuracy: 0.9555
# Epoch 23/50
# 62/62 [==============================] - 35s 561ms/step - loss: 0.0608 - accuracy: 0.9792 - val_loss: 0.2679 - val_accuracy: 0.9190
# Epoch 24/50
# 62/62 [==============================] - 35s 568ms/step - loss: 0.0567 - accuracy: 0.9838 - val_loss: 0.1840 - val_accuracy: 0.9494
# Epoch 25/50
# 62/62 [==============================] - 35s 565ms/step - loss: 0.0434 - accuracy: 0.9853 - val_loss: 0.3557 - val_accuracy: 0.9514
# Epoch 26/50
# 62/62 [==============================] - 35s 569ms/step - loss: 0.0405 - accuracy: 0.9853 - val_loss: 0.4171 - val_accuracy: 0.9494
# Epoch 27/50
# 62/62 [==============================] - 35s 566ms/step - loss: 0.0247 - accuracy: 0.9914 - val_loss: 0.3342 - val_accuracy: 0.9595
# Epoch 28/50
# 62/62 [==============================] - 35s 564ms/step - loss: 0.0908 - accuracy: 0.9807 - val_loss: 0.3298 - val_accuracy: 0.9251
# Epoch 29/50
# 62/62 [==============================] - 36s 586ms/step - loss: 0.0404 - accuracy: 0.9878 - val_loss: 0.3203 - val_accuracy: 0.9453
# Epoch 30/50
# 62/62 [==============================] - 38s 605ms/step - loss: 0.0299 - accuracy: 0.9924 - val_loss: 0.2523 - val_accuracy: 0.9514
# Epoch 31/50
# 62/62 [==============================] - 39s 637ms/step - loss: 0.0256 - accuracy: 0.9904 - val_loss: 0.2912 - val_accuracy: 0.9555
# Epoch 32/50
# 62/62 [==============================] - 37s 600ms/step - loss: 0.0869 - accuracy: 0.9757 - val_loss: 0.4413 - val_accuracy: 0.9393
# Epoch 33/50
# 62/62 [==============================] - 43s 702ms/step - loss: 0.0351 - accuracy: 0.9894 - val_loss: 0.3580 - val_accuracy: 0.9474
# Epoch 34/50
# 62/62 [==============================] - 41s 665ms/step - loss: 0.0371 - accuracy: 0.9863 - val_loss: 0.4116 - val_accuracy: 0.9453
# Epoch 35/50
# 62/62 [==============================] - 39s 627ms/step - loss: 0.0276 - accuracy: 0.9914 - val_loss: 0.4695 - val_accuracy: 0.9615
# Epoch 36/50
# 62/62 [==============================] - 41s 655ms/step - loss: 0.0179 - accuracy: 0.9934 - val_loss: 0.5307 - val_accuracy: 0.9413
# Epoch 37/50
# 62/62 [==============================] - 38s 611ms/step - loss: 0.0259 - accuracy: 0.9904 - val_loss: 0.6893 - val_accuracy: 0.9453
# Epoch 38/50
# 62/62 [==============================] - 39s 626ms/step - loss: 0.0621 - accuracy: 0.9878 - val_loss: 0.3154 - val_accuracy: 0.9433
# Epoch 39/50
# 62/62 [==============================] - 43s 691ms/step - loss: 0.0554 - accuracy: 0.9833 - val_loss: 0.3455 - val_accuracy: 0.9494
# Epoch 40/50
# 62/62 [==============================] - 39s 635ms/step - loss: 0.0370 - accuracy: 0.9888 - val_loss: 0.2778 - val_accuracy: 0.9615
# Epoch 41/50
# 62/62 [==============================] - 38s 617ms/step - loss: 0.0207 - accuracy: 0.9944 - val_loss: 0.4355 - val_accuracy: 0.9555
# Epoch 42/50
# 62/62 [==============================] - 39s 631ms/step - loss: 0.0438 - accuracy: 0.9868 - val_loss: 0.3083 - val_accuracy: 0.9393
# Epoch 43/50
# 62/62 [==============================] - 38s 612ms/step - loss: 0.0256 - accuracy: 0.9959 - val_loss: 0.3644 - val_accuracy: 0.9514
# Epoch 44/50
# 62/62 [==============================] - 37s 597ms/step - loss: 0.0165 - accuracy: 0.9934 - val_loss: 0.4791 - val_accuracy: 0.9615
# Epoch 45/50
# 62/62 [==============================] - 39s 636ms/step - loss: 0.0090 - accuracy: 0.9970 - val_loss: 0.4614 - val_accuracy: 0.9555
# Epoch 46/50
# 62/62 [==============================] - 35s 571ms/step - loss: 0.0260 - accuracy: 0.9929 - val_loss: 0.3719 - val_accuracy: 0.9413
# Epoch 47/50
# 62/62 [==============================] - 38s 618ms/step - loss: 0.0176 - accuracy: 0.9929 - val_loss: 0.3940 - val_accuracy: 0.9453
# Epoch 48/50
# 62/62 [==============================] - 35s 557ms/step - loss: 0.0485 - accuracy: 0.9868 - val_loss: 0.4121 - val_accuracy: 0.9393
# Epoch 49/50
# 62/62 [==============================] - 37s 592ms/step - loss: 0.1141 - accuracy: 0.9676 - val_loss: 0.2100 - val_accuracy: 0.9494
# Epoch 50/50
# 62/62 [==============================] - 40s 646ms/step - loss: 0.0582 - accuracy: 0.9812 - val_loss: 0.2890 - val_accuracy: 0.9372

# %%
acc = hist.history['accuracy']
val_acc = hist.history['val_accuracy']
loss = hist.history['loss']
val_loss = hist.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize = (16, 16))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label = 'Training Accuracy')
plt.plot(epochs_range, val_acc, label = 'Validation Accuracy')
plt.legend(loc = 'lower right')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')

plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label = 'Training Loss')
plt.plot(epochs_range, val_loss, label = 'Validation Loss')
plt.legend(loc = 'upper right')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')

plt.show()

# %%
pred_X = model.predict(X_test)
y_pred = np.argmax(pred_X, axis = 1)
y_test = np.argmax(y_test, axis = 1)
# Out:
# 14/14 [==============================] - 2s 127ms/step

# %%
cm = confusion_matrix(y_test, y_pred)
hm = sns.heatmap(cm, annot = True)
hm.set_xlabel("Predicted", fontsize = 14, labelpad = 14)
hm.xaxis.set_ticklabels(['closed eyes', 'eyes open', 'yawn', 'no yawn'], fontsize = 8)
hm.set_ylabel("Actual", fontsize = 14, labelpad = 14)
hm.yaxis.set_ticklabels(['closed eyes', 'eyes open', 'yawn', 'no yawn'], fontsize = 8)
hm.set_title("CNN Confusion Matrix", fontsize = 14, pad = 14)
# Out:
# Text(0.5, 1.0, 'CNN Confusion Matrix')

# %%
print(classification_report(y_test, y_pred, target_names = ['closed eyes', 'eyes open', 'yawn', 'no yawn']))
# Out:
#               precision    recall  f1-score   support
#
#  closed eyes       0.93      0.96      0.95       109
#    eyes open       0.86      0.98      0.91       109
#         yawn       0.95      0.94      0.94       109
#      no yawn       0.99      0.82      0.90       106
#
#     accuracy                           0.93       433
#    macro avg       0.93      0.93      0.93       433
# weighted avg       0.93      0.93      0.93       433

# %%
model.save('c:/Users/Dareen/OneDrive/Desktop/graduation/yawn_model.h5')
from keras.models import load_model

# Load the model
yawn_model = load_model('c:/Users/Dareen/OneDrive/Desktop/graduation/yawn_model.h5')

# %%
cap = cv2.VideoCapture('C:/Users/Dareen/OneDrive/Desktop/graduation/istockphoto-1437249423-640_adpp_is.mp4')
import IPython.display as ipd
import subprocess 
ipd.Video("C:/Users/Dareen/OneDrive/Desktop/graduation/istockphoto-1311193318-640_adpp_is.mp4",width=400,height=400)
cap.get(cv2.CAP_PROP_FRAME_COUNT)
hight = cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
width = cap.get(cv2.CAP_PROP_FRAME_WIDTH)
print(hight,width)
size = 244
no_channel = 3
# Out:
# 360.0 640.0

# %%
def preprocess_video(video_path, output_size=(224, 224)):

    frames = []
    
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
    
        frame = cv2.resize(frame, output_size)
        
        # Convert to RGB if not already
        if len(frame.shape) < 3 or frame.shape[2] == 1:
            frame = cv2.cvtColor(frame, cv2.COLOR_GRAY2RGB)
        
        frames.append(frame)
    
    cap.release()
    
    # Stack frames into a single numpy array
    video_array = np.stack(frames)
    
    return video_array

# Example usage:
video_path = 'C:/Users/Dareen/OneDrive/Desktop/graduation/istockphoto-1437249423-640_adpp_is.mp4'
processed_video = preprocess_video(video_path)

# Check the shape of the processed video
print(processed_video.shape)  # This should print (num_frames, height, width, channels)
# Out:
# (444, 224, 224, 3)

# %%
model.predict(processed_video)
# Out:
# 14/14 [==============================] - 1s 106ms/step
# array([[0., 0., 0., 1.],
#        [0., 0., 0., 1.],
#        [0., 0., 0., 1.],
#        ...,
#        [0., 1., 0., 0.],
#        [0., 1., 0., 0.],
#        [0., 1., 0., 0.]], dtype=float32)
